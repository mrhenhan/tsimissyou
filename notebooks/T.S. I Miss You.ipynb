# %%
import numpy as np
import matplotlib.pyplot as pyplot
import seaborn as sns
import pandas as pd
from pandas.plotting import autocorrelation_plot
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
temps = pd.read_csv("https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-min-temperatures.csv", index_col=0, header=0)

# %%
temps.plot(figsize=(20,15), title="Min Temperatures / Melbourne")
pyplot.savefig("min_temps.png", bbox_inches='tight')

# %%
pyplot.figure(figsize=(20,15))
autocorrelation_plot(temps)
pyplot.savefig("autocorr_mintemps.png", bbox_inches='tight')

# %%
result = seasonal_decompose(temps, model='additive', freq=365)
result.plot()

# %%
airline = pd.read_csv("airpass.csv", header=0, index_col=0)

# %%
airline.plot(figsize=(20,15), title="Int. Airline Passengers - Monthly")
pyplot.savefig("airline_seasonality_trend.png", bbox_inches='tight')

# %%
pyplot.figure(figsize=(20,15))
autocorrelation_plot(airline)
pyplot.savefig("autocorr_airline.png", bbox_inches='tight')

# %%
result = seasonal_decompose(airline, model='additive', freq=12)
result.plot()
pyplot.savefig("airpass_decompose.png", bbox_inches='tight')

# %%
sp = pd.read_csv("spdata.csv")
del sp["Unnamed: 0"]

# %%
sp.head()
# Out:
#        x
# 0  149.2
# 1  148.4
# 2  160.1
# 3  171.8
# 4  179.2

# %%
sp.plot(figsize=(20,15), title="Quarterly S&P Composite Index")
pyplot.savefig("sp_composite_index.png", bbox_inches='tight')

# %%
pyplot.figure(figsize=(20,15))
autocorrelation_plot(sp)
pyplot.savefig("autocorr_sp.png", bbox_inches='tight')

# %%
google = pd.read_csv("google.csv")
del google["Unnamed: 0"]
google.plot(figsize=(20,15), title="Daily Returns of Google Stock")
pyplot.savefig("google_stock_daily.png", bbox_inches='tight')

# %%
pyplot.figure(figsize=(20,15))
autocorrelation_plot(google)
pyplot.savefig("autocorr_google.png", bbox_inches='tight')

# %%
beer = pd.read_csv("beersales.csv")
del beer["Unnamed: 0"]
beer.plot(figsize=(20,15), title="Monthly beer sales in millions of barrels")
pyplot.savefig("beersales.png", bbox_inches='tight')

# %%
pyplot.figure(figsize=(20,15))
autocorrelation_plot(beer)
pyplot.savefig("autocorr_beer.png", bbox_inches='tight')
